# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mbpp_ranges = [1, 3, 5, 8, 12]
mbpp_plus_results = [47.226502174549423, 52.1341463415, 59.6036585366, 59.6036585366 , 59.6036585366]
filtered_mbpp_plus_results = [63.41903959213012, 67.6829268293, 76.0670731707, 76.0670731707, 76.0670731707]
# Plotting
plt.figure(figsize=(6, 6))
plus_oracle = [0.8236760265173695] * 5
# for each number in the lists above, times 100
plus_oracle = [x * 100 for x in plus_oracle]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
sns.lineplot(x=mbpp_ranges, y=mbpp_plus_results, label='MBR', marker='s', markersize=marker_size,
             linestyle='-', color=palette[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=filtered_mbpp_plus_results, label='Filter+MBR', linestyle='-', marker='s', markersize=marker_size,
             color=palette[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=plus_oracle, label='Oracle', linestyle='--', marker='s', markersize=marker_size,
             color=palette[5], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Test Cases', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=18,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=alpha)
plt.xticks(ticks=[1, 3, 5, 8, 12], labels=['1', '3', '5', '10', 'all'], fontsize=24) 
plt.yticks(np.arange(50, 90, 10), fontsize=24) 
plt.savefig('../figs/cl_13b_humaneval_test_cases.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mbpp_ranges = [1, 3, 5, 8, 12]
mbpp_plus_results = [58.43325010088563, 59.3670886076, 67.4050632911, 67.4050632911 , 67.2151898734]
filtered_mbpp_plus_results = [64.69159563120278, 66.0126582278, 74.9367088608, 74.9367088608, 74.746835443]
# Plotting
plt.figure(figsize=(6, 6))
plus_oracle = [0.7802807540316617] * 5
# for each number in the lists above, times 100
plus_oracle = [x * 100 for x in plus_oracle]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
sns.lineplot(x=mbpp_ranges, y=mbpp_plus_results, label='MBR', marker='s', markersize=marker_size,
             linestyle='-', color=palette[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=filtered_mbpp_plus_results, label='Filter+MBR', linestyle='-', marker='s', markersize=marker_size,
             color=palette[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=plus_oracle, label='Oracle', linestyle='--', marker='s', markersize=marker_size,
             color=palette[5], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Test Cases', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=18,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=alpha)
plt.xticks(ticks=[1, 3, 5, 8, 12], labels=['1', '3', '5', '10', 'all'], fontsize=24) 
plt.yticks(np.arange(60, 80, 5), fontsize=24) 
plt.savefig('../figs/cl_13b_mbpp_test_cases.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#cl13b + humaneval


mean_base = [0.35844512195121947]
mean_plus = [0.31094512195121954]



ks = [5,10,20,25,50]
mbr_base_scores = [52.5914634146, 57.4695121951, 60.7317073171, 60.3658536585, 61.2804878049]
mbr_ape_base_scores = [54.3445121951, 58.4756097561, 61.7073170732, 60.9756097561, 61.737804878]
ape_mbr_base_scores = [55.5945121951, 59.0548780488, 61.2195121951, 61.737804878, 62.6524390244]
mbr_plus_scores = [47.6219512195, 53.3536585366, 57.743902439, 57.4695121951, 59.6036585366]
mbr_ape_plus_scores = [49.3140243902, 54.3597560976, 58.6585365854, 58.0792682927, 60.0609756098]
ape_mbr_plus_scores = [50.868902439, 55.5182926829, 58.7804878049, 59.5274390244, 61.4329268293]

filtering_mbr_base_scores = [62.4695121951, 69.512195122, 75.1219512195, 76.5243902439, 80.487804878]
filtering_mbr_ape_base_scores = [63.9634146341, 70.1829268293, 75.6707317073, 77.1341463415, 80.9451219512]
filtering_ape_mbr_base_scores = [65.8079268293, 71.9512195122, 76.7073170732, 77.8963414634, 81.5548780488]
filtering_mbr_plus_scores = [56.3414634146, 63.9634146341, 70.1219512195, 71.5701219512, 76.0670731707]
filtering_mbr_ape_plus_scores = [57.8353658537, 64.7256097561, 70.7926829268, 72.1798780488, 76.5243902439]
filtering_ape_mbr_plus_scores = [60.0762195122, 67.0426829268, 72.3780487805, 73.4756097561, 77.5914634146]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(6, 6))
base_oracle = [0.6541424156187059, 0.7455289849360687, 0.8158637486723943, 0.8353367136930824, 0.8871337081720749]
plus_oracle = [0.5828711248820249, 0.6784064736188292, 0.7519489554575006, 0.7715367208653594, 0.8236760265173695]
one_round_sd_ut_base = [0.6923435298791103, 0.772352631766236, 0.8376022877528296, 0.8559634909904752, 0.9041317538890004]
one_round_sd_ut_plus = [0.6234893698347173, 0.7094361271502048, 0.7766669027126094, 0.794848127563961, 0.843336018850883]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[2], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='MBR-Filter', linestyle='--', marker='o', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)

palette_dashed = sns.color_palette("dark:salmon_r", 6)  # Define a palette with 2 colors for dashed lines
sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='s', markersize=marker_size, color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='Filter+MBR', marker='s', markersize=marker_size, color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=base_oracle, label='Oracle', marker='s', markersize=marker_size, linestyle='--', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=16,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='upper left', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=1)
plt.xticks(np.arange(10, 60, 10), fontsize=24) 
plt.yticks(np.arange(50, 100, 10), fontsize=24)  # Adjust y-axis scale in steps of 5
plt.savefig('../figs/cl_13b_humaneval_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#cl13b + mbpp

import numpy as np
mean_base = [0.5245316455696203]
mean_plus = [0.43508860759493667]

ks = [5,10,20,25,50]
mbr_base_scores = [67.1962025316, 70.7215189873, 72.835443038, 73.164556962, 73.9240506329]
mbr_ape_base_scores = [69.5949367089, 71.8481012658, 73.3417721519, 73.8291139241, 74.3670886076]
ape_mbr_base_scores = [70.246835443, 72.5063291139, 73.4683544304, 73.7025316456, 74.4303797468]
mbr_plus_scores = [58.7848101266, 62.6455696203, 65.1392405063, 65.7911392405, 67.2151898734]
mbr_ape_plus_scores = [60.4556962025, 63.2025316456, 65.1392405063, 65.664556962, 66.9620253165]
ape_mbr_plus_scores = [61.7974683544, 64.7848101266, 66.4050632911, 66.9303797468, 68.3544303797]

filtering_mbr_base_scores = [73.7341772152, 78.4430379747, 81.4936708861, 82.2784810127, 84.0506329114]
filtering_mbr_ape_base_scores = [75.6202531646, 79.1265822785, 81.4683544304, 82.3417721519, 83.9240506329]
filtering_ape_mbr_base_scores = [77.3037974684, 80.5569620253, 82.6329113924, 83.4493670886, 84.9367088608]
filtering_mbr_plus_scores = [62.8734177215, 67.746835443, 71.2658227848, 72.4367088608, 74.746835443]
filtering_mbr_ape_plus_scores = [64.2848101266, 68.0759493671, 70.9367088608, 72.0886075949, 74.2405063291]
filtering_ape_mbr_plus_scores = [66.2278481013, 70.2151898734, 72.8607594937, 74.0189873418, 76.2025316456]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(6, 6))
base_oracle = [0.7577799895925382, 0.8118292075703085, 0.8492626074843331, 0.8588183645013925, 0.8838362729476953]
plus_oracle = [0.6440075724220018, 0.6974405959710274, 0.7395257913333202, 0.7509011317516285, 0.7802807540316617]
one_round_sd_ut_base = [0.7983618536957995, 0.8379971274412924, 0.8666824639813115, 0.8746837223120333, 0.8976502022856077]
one_round_sd_ut_plus = [0.6794442164134693, 0.7231854781432838, 0.757969046390868, 0.7674050408272838, 0.7925232501556393]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[2], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='MBR-Filter', linestyle='--', marker='o', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)

palette_dashed = sns.color_palette("dark:salmon_r", 6)  # Define a palette with 2 colors for dashed lines
sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='s', markersize=marker_size, color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='Filter+MBR', marker='s', markersize=marker_size, color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=base_oracle, label='Oracle', marker='s', markersize=marker_size, linestyle='--', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=16,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='upper left', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=1)
plt.xticks(np.arange(10, 60, 10), fontsize=24) 
plt.yticks(np.arange(70, 90, 5), fontsize=24)  # Adjust y-axis scale in steps of 5
plt.savefig('../figs/cl_13b_mbpp_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#humaneval

ks = [5,10,20,25,50]
mbr_base_scores = [52.5914634146, 57.4695121951, 60.7317073171, 60.3658536585, 61.2804878049]
mbr_ape_base_scores = [54.3445121951, 58.4756097561, 61.7073170732, 60.9756097561, 61.737804878]
ape_mbr_base_scores = [55.5945121951, 59.0548780488, 61.2195121951, 61.737804878, 62.6524390244]
mbr_plus_scores = [47.6219512195, 53.3536585366, 57.743902439, 57.4695121951, 59.6036585366]
mbr_ape_plus_scores = [49.3140243902, 54.3597560976, 58.6585365854, 58.0792682927, 60.0609756098]
ape_mbr_plus_scores = [50.868902439, 55.5182926829, 58.7804878049, 59.5274390244, 61.4329268293]

filtering_mbr_base_scores = [62.4695121951, 69.512195122, 75.1219512195, 76.5243902439, 80.487804878]
filtering_mbr_ape_base_scores = [63.9634146341, 70.1829268293, 75.6707317073, 77.1341463415, 80.9451219512]
filtering_ape_mbr_base_scores = [65.8079268293, 71.9512195122, 76.7073170732, 77.8963414634, 81.5548780488]
filtering_mbr_plus_scores = [56.3414634146, 63.9634146341, 70.1219512195, 71.5701219512, 76.0670731707]
filtering_mbr_ape_plus_scores = [57.8353658537, 64.7256097561, 70.7926829268, 72.1798780488, 76.5243902439]
filtering_ape_mbr_plus_scores = [60.0762195122, 67.0426829268, 72.3780487805, 73.4756097561, 77.5914634146]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
base_oracle = [0.6541424156187059, 0.7455289849360687, 0.8158637486723943, 0.8353367136930824, 0.8871337081720749]
plus_oracle = [0.5828711248820249, 0.6784064736188292, 0.7519489554575006, 0.7715367208653594, 0.8236760265173695]
one_round_sd_ut_base = [0.6923435298791103, 0.772352631766236, 0.8376022877528296, 0.8559634909904752, 0.9041317538890004]
one_round_sd_ut_plus = [0.6234893698347173, 0.7094361271502048, 0.7766669027126094, 0.794848127563961, 0.843336018850883]

base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

plt.figure(figsize=(6, 6))
alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 10)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', marker='o', linestyle='--', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='SD-1-Filter', linestyle='--', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='SD-Multi-Filter', marker='o', color=palette[7], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Pass@k SD', marker='o', color=palette[9], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)


palette_blue = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors

palette_dashed = sns.color_palette("dark:salmon_r", 10)  # Define a palette with 2 colors for dashed lines
#sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR+', marker='o', linestyle='--', color=palette_dashed[0], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='MBR-Filter+', marker='o', linestyle='--', color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=mbr_ape_base_scores, 
             #label='SD-1', 
             marker='s', markersize=marker_size,
             color=palette_blue[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=ape_mbr_base_scores, 
             #label='SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_blue[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, 
             #label='Filter+SD-1', 
             marker='s', markersize=marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, 
             #label='Filter+SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_dashed[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=one_round_sd_ut_base, 
             #label='Oracle SD', 
             marker='s', markersize=marker_size,
             linestyle='--', color=palette_dashed[6], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=plus_oracle, label='Pass@k+', marker='o', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
#plt.legend(
#    fontsize=14,
#    #title='methods', 
#    #title_fontsize='16',
#    shadow=False, 
#    fancybox=True, 
#    loc='right', 
#    framealpha=0.3,
#    #bbox_to_anchor=(1.05, 1) 
#)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(fontsize=24) 
plt.yticks(np.arange(50,100,10), fontsize=24) 
plt.savefig('../figs/cl_13b_humaneval_sd_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#mbpp

# create lists for results above
ks = [5,10,20,25,50]
mbr_base_scores = [67.1962025316, 70.7215189873, 72.835443038, 73.164556962, 73.9240506329]
mbr_ape_base_scores = [69.5949367089, 71.8481012658, 73.3417721519, 73.8291139241, 74.3670886076]
ape_mbr_base_scores = [70.246835443, 72.5063291139, 73.4683544304, 73.7025316456, 74.4303797468]
mbr_plus_scores = [58.7848101266, 62.6455696203, 65.1392405063, 65.7911392405, 67.2151898734]
mbr_ape_plus_scores = [60.4556962025, 63.2025316456, 65.1392405063, 65.664556962, 66.9620253165]
ape_mbr_plus_scores = [61.7974683544, 64.7848101266, 66.4050632911, 66.9303797468, 68.3544303797]

filtering_mbr_base_scores = [73.7341772152, 78.4430379747, 81.4936708861, 82.2784810127, 84.0506329114]
filtering_mbr_ape_base_scores = [75.6202531646, 79.1265822785, 81.4683544304, 82.3417721519, 83.9240506329]
filtering_ape_mbr_base_scores = [77.3037974684, 80.5569620253, 82.6329113924, 83.4493670886, 84.9367088608]
filtering_mbr_plus_scores = [62.8734177215, 67.746835443, 71.2658227848, 72.4367088608, 74.746835443]
filtering_mbr_ape_plus_scores = [64.2848101266, 68.0759493671, 70.9367088608, 72.0886075949, 74.2405063291]
filtering_ape_mbr_plus_scores = [66.2278481013, 70.2151898734, 72.8607594937, 74.0189873418, 76.2025316456]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
base_oracle = [0.7577799895925382, 0.8118292075703085, 0.8492626074843331, 0.8588183645013925, 0.8838362729476953]
plus_oracle = [0.6440075724220018, 0.6974405959710274, 0.7395257913333202, 0.7509011317516285, 0.7802807540316617]
one_round_sd_ut_base = [0.7983618536957995, 0.8379971274412924, 0.8666824639813115, 0.8746837223120333, 0.8976502022856077]
one_round_sd_ut_plus = [0.6794442164134693, 0.7231854781432838, 0.757969046390868, 0.7674050408272838, 0.7925232501556393]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

plt.figure(figsize=(6, 6))
alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 10)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', marker='o', linestyle='--', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='SD-1-Filter', linestyle='--', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='SD-Multi-Filter', marker='o', color=palette[7], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Pass@k SD', marker='o', color=palette[9], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)


palette_blue = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors

palette_dashed = sns.color_palette("dark:salmon_r", 10)  # Define a palette with 2 colors for dashed lines
#sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR+', marker='o', linestyle='--', color=palette_dashed[0], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='MBR-Filter+', marker='o', linestyle='--', color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', 
             marker='s', markersize=marker_size,
             color=palette_blue[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_blue[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='Filter+SD-1', 
             marker='s', markersize=marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='Filter+SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_dashed[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Oracle SD', 
             marker='s', markersize=marker_size,
             linestyle='--', color=palette_dashed[6], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=plus_oracle, label='Pass@k+', marker='o', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=14,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(fontsize=24) 
plt.yticks(np.arange(70,95,5), fontsize=24) 
plt.savefig('../figs/cl_13b_mbpp_sd_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches = 0.01)
plt.show()
