# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#base 
humaneval_ranges = [1, 3, 5, 8, 13] #these are just used for defining the positions
humaneval_plus_results = [40.340289764251464, 45.1219512195, 50.0, 50.0, 49.5426829268]
filtered_humaneval_plus_results = [50.48158412700252, 63.4146341463, 70.2743902439, 70.2743902439, 70.1219512195]

# Plotting
plt.figure(figsize=(6, 6))
plus_oracle = [0.761755427566514] * 5
# for each number in the lists above, times 100
plus_oracle = [x * 100 for x in plus_oracle]

alpha = 0.9
line_width = 3
marker_size = 8 
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
sns.lineplot(x=humaneval_ranges, y=humaneval_plus_results, 
             #label='MBR', 
             marker='s', markersize=marker_size,
             linestyle='-', color=palette[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=humaneval_ranges, y=filtered_humaneval_plus_results, 
             #label='MBR-Filter', 
             linestyle='-', marker='s', markersize=marker_size,
             color=palette[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=humaneval_ranges, y=plus_oracle, 
             #label='Oracle', 
             linestyle='--', marker='s', markersize=marker_size,
             color=palette[5], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Test Cases', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
#plt.legend(
#    fontsize=18,
#    #title='methods', 
#    #title_fontsize='16',
#    shadow=False, 
#    fancybox=True, 
#    loc='lower right', 
#    framealpha=0.3,
#    #bbox_to_anchor=(1.05, 1) 
#)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(ticks=[1, 3, 5, 8, 13], labels=['1', '10', '20', '50', 'all'], fontsize=24) 
plt.yticks(np.arange(40, 80, 10), fontsize=24) 
plt.savefig('../figs/humaneval_test_cases.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mbpp_ranges = [1, 3, 5, 8, 12]
mbpp_plus_results = [51.53451054748253, 51.4556962025, 57.8481012658, 57.8481012658 ,57.8481012658]
filtered_mbpp_plus_results = [60.81458614625988, 61.3291139241, 69.4303797468, 69.4303797468, 69.3037974684]

# Plotting
plt.figure(figsize=(6, 6))
plus_oracle = [0.7200347118506785] * 5
# for each number in the lists above, times 100
plus_oracle = [x * 100 for x in plus_oracle]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
sns.lineplot(x=mbpp_ranges, y=mbpp_plus_results, label='MBR', marker='s', markersize=marker_size,
             linestyle='-', color=palette[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=filtered_mbpp_plus_results, label='Filter+MBR', linestyle='-', marker='s', markersize=marker_size,
             color=palette[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=plus_oracle, label='Oracle', linestyle='--', marker='s', markersize=marker_size,
             color=palette[5], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Test Cases', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=18,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=alpha)
plt.xticks(ticks=[1, 3, 5, 8, 12], labels=['1', '3', '5', '10', 'all'], fontsize=24) 
plt.yticks(fontsize=24) 
plt.savefig('../figs/mbpp_test_cases.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#humaneval


mean_base = [0.3413109756097561]
mean_plus = [0.3020426829268293]


ks = [5,10,20,25,50]
mbr_base_scores = [45.9146341463, 49.3902439024, 50.6097560976, 50.9908536585, 52.1341463415]
mbr_ape_base_scores = [46.8292682927, 49.6341463415, 50.7317073171, 50.9146341463, 51.9817073171]
ape_mbr_base_scores = [48.0792682927, 50.4268292683, 51.7073170732, 51.5243902439, 52.4390243902]
mbr_plus_scores = [42.118902439, 46.2804878049, 48.2926829268, 48.5518292683, 49.5426829268]
mbr_ape_plus_scores = [42.987804878, 46.5243902439, 48.2926829268, 48.5518292683, 49.5426829268]
ape_mbr_plus_scores = [44.2835365854, 47.4695121951, 49.3292682927, 49.0853658537, 50.0]

filtering_mbr_base_scores = [55.7012195122, 62.7134146341, 68.9024390244, 70.1981707317, 74.5426829268]
filtering_mbr_ape_base_scores = [57.012195122, 63.2317073171, 69.0853658537, 70.4268292683, 74.3902439024]
filtering_ape_mbr_base_scores = [58.7042682927, 65.1219512195, 71.2195121951, 72.4085365854, 76.5243902439]
filtering_mbr_plus_scores = [50.3201219512, 57.4390243902, 64.3902439024, 65.243902439, 70.1219512195]
filtering_mbr_ape_plus_scores = [51.5396341463, 57.8963414634, 64.4512195122, 65.5487804878, 70.1219512195]
filtering_ape_mbr_plus_scores = [53.4603658537, 59.9695121951, 66.8292682927, 67.6067073171, 72.256097561]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(6, 6))
base_oracle = [0.5864145888102014, 0.6721472276082698, 0.7458570149045832, 0.766968676070771, 0.8238279449187789]
plus_oracle = [0.5281954757091621, 0.612347957461032, 0.684540110168908, 0.7051600032015305, 0.761755427566514]
one_round_sd_ut_base = [0.6178384300580549, 0.7004704922057142, 0.7737681780475395, 0.7943278112469883, 0.8477372032768344]
one_round_sd_ut_plus = [0.5596479563779274, 0.6402425390552481, 0.7108751967350315, 0.7307077355551483, 0.7836077111474856]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
#one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
#one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[2], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='MBR-Filter', linestyle='--', marker='o', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)

palette_dashed = sns.color_palette("dark:salmon_r", 6)  # Define a palette with 2 colors for dashed lines
sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR', marker='s', markersize=marker_size, color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='Filter+MBR', marker='s', markersize=marker_size, color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=plus_oracle, label='Oracle', marker='s', markersize=marker_size, linestyle='--', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=16,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='upper left', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=1)
plt.xticks(np.arange(10, 60, 10), fontsize=24) 
plt.yticks(np.arange(50, 90, 10), fontsize=24)  # Adjust y-axis scale in steps of 5
plt.savefig('../figs/humaneval_candidates.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#### mbpp

mean_base = [0.5014303797468355]
mean_plus = [0.41886075949367085]

# create lists for results above
ks = [5,10,20,25,50]

mbr_base_scores = [59.4556962025, 62.1392405063, 63.5696202532, 63.6708860759, 63.9873417722]
mbr_ape_base_scores = [62.7025316456, 64.5569620253, 65.4430379747, 65.4113924051, 65.7594936709]
ape_mbr_base_scores = [63.6582278481, 65.3670886076, 66.3291139241, 66.1392405063, 66.3291139241]
mbr_plus_scores = [51.9050632911, 55.0759493671, 56.835443038, 57.1202531646, 57.8481012658]
mbr_ape_plus_scores = [53.9810126582, 56.5443037975, 57.8987341772, 58.1329113924, 59.0506329114]
ape_mbr_plus_scores = [55.1962025316, 57.6708860759, 59.5189873418, 59.5886075949, 60.3797468354]

filtering_mbr_base_scores = [66.9303797468, 72.1012658228, 75.6708860759, 76.7721518987, 78.9873417722]
filtering_mbr_ape_base_scores = [69.8227848101, 73.7848101266, 76.4810126582, 77.4367088608, 79.3037974684]
filtering_ape_mbr_base_scores = [71.4556962025, 75.4810126582, 78.5063291139, 79.3670886076, 81.2658227848]
filtering_mbr_plus_scores = [57.1518987342, 62.0506329114, 65.5189873418, 66.8037974684, 69.3037974684]
filtering_mbr_ape_plus_scores = [58.835443038, 62.746835443, 65.6202531646, 66.8987341772, 69.1772151899]
filtering_ape_mbr_plus_scores = [60.5253164557, 64.835443038, 68.5063291139, 69.5886075949, 72.0886075949]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(6, 6))
base_oracle = [0.6901029196891556, 0.7473957372262354, 0.792147703273061, 0.8038140906622494, 0.8323884033013811]
plus_oracle = [0.5846919197887419, 0.6374577334858043, 0.6792695825316757, 0.6905503512152964, 0.7200347118506785]
one_round_sd_ut_base = [0.7387548921190633, 0.7870246607000371, 0.8235968359709959, 0.8329249826882055, 0.8553387152788938]
one_round_sd_ut_plus = [0.6193335030071491, 0.6672469493331259, 0.7065348970566764, 0.7176315962991736, 0.7471991493266931]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
#one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
#one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[2], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='MBR-Filter', linestyle='--', marker='o', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)

palette_dashed = sns.color_palette("dark:salmon_r", 6)  # Define a palette with 2 colors for dashed lines
sns.lineplot(x=ks, y=mbr_plus_scores, 
             #label='MBR', 
             marker='s', markersize = marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_plus_scores, 
             #label='MBR-Filter', 
             marker='s', markersize = marker_size,
             color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=plus_oracle, 
             #label='Oracle', 
             marker='s', markersize = marker_size,
             linestyle='--', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
#plt.legend(
#    fontsize=16,
#    #title='methods', 
#    #title_fontsize='16',
#    shadow=False, 
#    fancybox=True, 
#    loc='upper left', 
#    framealpha=0.3,
#    #bbox_to_anchor=(1.05, 1) 
#)
plt.grid(True, linestyle='-', linewidth=1, alpha=1)
plt.xticks(np.arange(10, 60, 10), fontsize=24) 
plt.yticks(np.arange(50, 75, 5), fontsize=24)  # Adjust y-axis scale in steps of 5
plt.savefig('../figs/mbpp_candidates.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#humaneval

ks = [5,10,20,25,50]
mbr_base_scores = [45.9146341463, 49.3902439024, 50.6097560976, 50.9908536585, 52.1341463415]
mbr_ape_base_scores = [46.8292682927, 49.6341463415, 50.7317073171, 50.9146341463, 51.9817073171]
ape_mbr_base_scores = [48.0792682927, 50.4268292683, 51.7073170732, 51.5243902439, 52.4390243902]
mbr_plus_scores = [42.118902439, 46.2804878049, 48.2926829268, 48.5518292683, 49.5426829268]
mbr_ape_plus_scores = [42.987804878, 46.5243902439, 48.2926829268, 48.5518292683, 49.5426829268]
ape_mbr_plus_scores = [44.2835365854, 47.4695121951, 49.3292682927, 49.0853658537, 50.0]

filtering_mbr_base_scores = [55.7012195122, 62.7134146341, 68.9024390244, 70.1981707317, 74.5426829268]
filtering_mbr_ape_base_scores = [57.012195122, 63.2317073171, 69.0853658537, 70.4268292683, 74.3902439024]
filtering_ape_mbr_base_scores = [58.7042682927, 65.1219512195, 71.2195121951, 72.4085365854, 76.5243902439]
filtering_mbr_plus_scores = [50.3201219512, 57.4390243902, 64.3902439024, 65.243902439, 70.1219512195]
filtering_mbr_ape_plus_scores = [51.5396341463, 57.8963414634, 64.4512195122, 65.5487804878, 70.1219512195]
filtering_ape_mbr_plus_scores = [53.4603658537, 59.9695121951, 66.8292682927, 67.6067073171, 72.256097561]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
base_oracle = [0.5864145888102014, 0.6721472276082698, 0.7458570149045832, 0.766968676070771, 0.8238279449187789]
plus_oracle = [0.5281954757091621, 0.612347957461032, 0.684540110168908, 0.7051600032015305, 0.761755427566514]
one_round_sd_ut_base = [0.6178384300580549, 0.7004704922057142, 0.7737681780475395, 0.7943278112469883, 0.8477372032768344]
one_round_sd_ut_plus = [0.5596479563779274, 0.6402425390552481, 0.7108751967350315, 0.7307077355551483, 0.7836077111474856]

base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

plt.figure(figsize=(6, 6))
alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 10)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', marker='o', linestyle='--', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='SD-1-Filter', linestyle='--', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='SD-Multi-Filter', marker='o', color=palette[7], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Pass@k SD', marker='o', color=palette[9], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)


palette_blue = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors

palette_dashed = sns.color_palette("dark:salmon_r", 10)  # Define a palette with 2 colors for dashed lines
#sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR+', marker='o', linestyle='--', color=palette_dashed[0], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='MBR-Filter+', marker='o', linestyle='--', color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=mbr_ape_plus_scores, 
             #label='SD-1', 
             marker='s', markersize=marker_size,
             color=palette_blue[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=ape_mbr_plus_scores, 
             #label='SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_blue[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_ape_plus_scores, 
             #label='Filter+SD-1', 
             marker='s', markersize=marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_ape_mbr_plus_scores, 
             #label='Filter+SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_dashed[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=one_round_sd_ut_plus, 
             #label='Oracle SD', 
             marker='s', markersize=marker_size,
             linestyle='--', color=palette_dashed[6], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=plus_oracle, label='Pass@k+', marker='o', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
#plt.legend(
#    fontsize=14,
#    #title='methods', 
#    #title_fontsize='16',
#    shadow=False, 
#    fancybox=True, 
#    loc='right', 
#    framealpha=0.3,
#    #bbox_to_anchor=(1.05, 1) 
#)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(fontsize=24) 
plt.yticks(np.arange(40,90,10), fontsize=24) 
plt.savefig('../figs/humaneval_sd_candidates.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#mbpp

# create lists for results above
ks = [5,10,20,25,50]
mbr_base_scores = [59.4556962025, 62.1392405063, 63.5696202532, 63.6708860759, 63.9873417722]
mbr_ape_base_scores = [62.7025316456, 64.5569620253, 65.4430379747, 65.4113924051, 65.7594936709]
ape_mbr_base_scores = [63.6582278481, 65.3670886076, 66.3291139241, 66.1392405063, 66.3291139241]
mbr_plus_scores = [51.9050632911, 55.0759493671, 56.835443038, 57.1202531646, 57.8481012658]
mbr_ape_plus_scores = [53.9810126582, 56.5443037975, 57.8987341772, 58.1329113924, 59.0506329114]
ape_mbr_plus_scores = [55.1962025316, 57.6708860759, 59.5189873418, 59.5886075949, 60.3797468354]

filtering_mbr_base_scores = [66.9303797468, 72.1012658228, 75.6708860759, 76.7721518987, 78.9873417722]
filtering_mbr_ape_base_scores = [69.8227848101, 73.7848101266, 76.4810126582, 77.4367088608, 79.3037974684]
filtering_ape_mbr_base_scores = [71.4556962025, 75.4810126582, 78.5063291139, 79.3670886076, 81.2658227848]
filtering_mbr_plus_scores = [57.1518987342, 62.0506329114, 65.5189873418, 66.8037974684, 69.3037974684]
filtering_mbr_ape_plus_scores = [58.835443038, 62.746835443, 65.6202531646, 66.8987341772, 69.1772151899]
filtering_ape_mbr_plus_scores = [60.5253164557, 64.835443038, 68.5063291139, 69.5886075949, 72.0886075949]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
base_oracle = [0.6901029196891556, 0.7473957372262354, 0.792147703273061, 0.8038140906622494, 0.8323884033013811]
plus_oracle = [0.5846919197887419, 0.6374577334858043, 0.6792695825316757, 0.6905503512152964, 0.7200347118506785]
one_round_sd_ut_base = [0.7387548921190633, 0.7870246607000371, 0.8235968359709959, 0.8329249826882055, 0.8553387152788938]
one_round_sd_ut_plus = [0.6193335030071491, 0.6672469493331259, 0.7065348970566764, 0.7176315962991736, 0.7471991493266931]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

plt.figure(figsize=(6, 6))
alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 10)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', marker='o', linestyle='--', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='SD-1-Filter', linestyle='--', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='SD-Multi-Filter', marker='o', color=palette[7], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Pass@k SD', marker='o', color=palette[9], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)


palette_blue = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors

palette_dashed = sns.color_palette("dark:salmon_r", 10)  # Define a palette with 2 colors for dashed lines
#sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR+', marker='o', linestyle='--', color=palette_dashed[0], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='MBR-Filter+', marker='o', linestyle='--', color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=mbr_ape_plus_scores, label='SD-1', 
             marker='s', markersize=marker_size,
             color=palette_blue[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=ape_mbr_plus_scores, label='SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_blue[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_ape_plus_scores, label='Filter+SD-1', 
             marker='s', markersize=marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_ape_mbr_plus_scores, label='Filter+SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_dashed[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=one_round_sd_ut_plus, label='Oracle SD', 
             marker='s', markersize=marker_size,
             linestyle='--', color=palette_dashed[6], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=plus_oracle, label='Pass@k+', marker='o', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=14,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(fontsize=24) 
plt.yticks(np.arange(60,80,5), fontsize=24) 
plt.savefig('../figs/mbpp_sd_candidates.jpg', dpi=300, bbox_inches='tight', pad_inches = 0.01)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define the values
greedy_cl7b_humaneval_plus = 39.02439024390244
doce_cl7b_humaneval_plus = 72.256097561

greedy_cl7b_mbpp_plus = 44.81012658227848
doce_cl7b_mbpp_plus = 72.0886075949

greedy_cl13b_humaneval_plus = 39.63414634146341
doce_cl13b_humaneval_plus = 77.5914634146

greedy_cl13b_mbpp_plus = 52.65822784810127
doce_cl13b_mbpp_plus = 76.2025316456

greedy_ds6p7b_humaneval_plus = 76.82926829268293
doce_ds6p7b_humaneval_plus = 90.7012195122

greedy_ds6p7b_mbpp_plus = 64.30379746835443
doce_ds6p7b_mbpp_plus = 82.8481012658

# Sample data with categories having multiple groups
data = {
    'Task': ['HumanEval+', 'MBPP+', 'HumanEval+', 'MBPP+', 'HumanEval+', 'MBPP+'],
    'Model': ['CL-7B-Instruct', 'CL-7B-Instruct', 'DS-6.7B-Instruct', 'DS-6.7B-Instruct', 'CL-13B-Instruct', 'CL-13B-Instruct'],
    'Values': [doce_cl7b_humaneval_plus - greedy_cl7b_humaneval_plus, 
               doce_cl7b_mbpp_plus - greedy_cl7b_mbpp_plus, 
               doce_ds6p7b_humaneval_plus - greedy_ds6p7b_humaneval_plus, 
               doce_ds6p7b_mbpp_plus - greedy_ds6p7b_mbpp_plus,
               doce_cl13b_humaneval_plus - greedy_cl13b_humaneval_plus, 
               doce_cl13b_mbpp_plus - greedy_cl13b_mbpp_plus,]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Define a custom palette with colors for categories
palette = {'HumanEval+': '#267cbc', #'#1f77b4', 
           'MBPP+': '#fe7f8f', #'#ff7f0e'
               }

# Set the style and context
sns.set(style="whitegrid", context="talk")

# Create the horizontal bar plot with categories and colors
plt.figure(figsize=(8, 4))  # Increase figure size for better aesthetics
ax = sns.barplot(x='Values', y='Model', hue='Task', data=df, palette=palette, errorbar=None, dodge=True)

# Add titles and labels
plt.xlabel('Improvement in Exec Acc', fontsize=16
           #, weight='bold'
           )

# Customize the axes
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

# Remove the "Model" label from y-axis
ax.set_ylabel('')

# Add grid lines for better readability
ax.xaxis.grid(True, linestyle='--', linewidth=1)
ax.yaxis.grid(False)

# Set x-axis range and stride
ax.set_xlim(0, 41)  # Increase the x-axis limit to leave more space on the right
ax.xaxis.set_major_locator(plt.MultipleLocator(10))

# Add value labels to each bar
for p in ax.patches:
    if p.get_width() > 0:  # Only add labels for non-zero values
        ax.annotate(format(p.get_width(), '.1f'),
                    (p.get_width(), p.get_y() + p.get_height() / 2),
                    ha='center', va='center',
                    xytext=(10, 0),
                    textcoords='offset points',
                    fontsize=16, color='black'
                    #, weight='bold'
                    )

# Adjust bar thickness and transparency
for patch in ax.patches:
    patch.set_height(0.4)  # Adjust height to make bars slightly thicker
    patch.set_alpha(0.8)  # Set transparency to 0.8

# Create a smaller legend inside the plot
ax.legend(title="Task", loc='right', frameon=True, fontsize=16, title_fontsize=16)

# Rotate y-axis labels
plt.yticks(rotation=45, ha='right')

# Adjust layout to prevent clipping of rotated labels
plt.tight_layout()

# Save and show the plot
plt.savefig('../figs/model_improvement.jpg', dpi=300, bbox_inches='tight', pad_inches = 0.01)
plt.show()
