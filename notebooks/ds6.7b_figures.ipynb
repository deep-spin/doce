# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mbpp_ranges = [1, 3, 5, 8, 12]
mbpp_plus_results = [71.68475992845609, 76.3719512195, 85.5182926829, 85.5182926829 ,85.5182926829]
filtered_mbpp_plus_results = [78.73245667777552, 80.7926829268, 90.7012195122, 90.7012195122, 90.7012195122]
# Plotting
plt.figure(figsize=(6, 6))
plus_oracle = [0.9323522266778692] * 5
# for each number in the lists above, times 100
plus_oracle = [x * 100 for x in plus_oracle]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
sns.lineplot(x=mbpp_ranges, y=mbpp_plus_results, label='MBR', marker='s', markersize=marker_size,
             linestyle='-', color=palette[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=filtered_mbpp_plus_results, label='Filter+MBR', linestyle='-', marker='s', markersize=marker_size,
             color=palette[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=plus_oracle, label='Oracle', linestyle='--', marker='s', markersize=marker_size,
             color=palette[5], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Test Cases', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=18,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=alpha)
plt.xticks(ticks=[1, 3, 5, 8, 12], labels=['1', '3', '5', '10', 'all'], fontsize=24) 
plt.yticks(fontsize=24) 
plt.savefig('../figs/ds_6.7b_humaneval_test_cases.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mbpp_ranges = [1, 3, 5, 8, 12]
mbpp_plus_results = [69.66886552158191, 70.0632911392, 78.7974683544, 78.7974683544 ,78.6075949367]
filtered_mbpp_plus_results = [72.6060766929703, 73.1012658228, 82.2784810127, 82.2784810127, 82.0886075949]
# Plotting
plt.figure(figsize=(6, 6))
plus_oracle = [0.8564293970358527] * 5
# for each number in the lists above, times 100
plus_oracle = [x * 100 for x in plus_oracle]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
sns.lineplot(x=mbpp_ranges, y=mbpp_plus_results, label='MBR', marker='s', markersize=marker_size,
             linestyle='-', color=palette[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=filtered_mbpp_plus_results, label='Filter+MBR', linestyle='-', marker='s', markersize=marker_size,
             color=palette[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=mbpp_ranges, y=plus_oracle, label='Oracle', linestyle='--', marker='s', markersize=marker_size,
             color=palette[5], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Test Cases', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=18,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=alpha)
plt.xticks(ticks=[1, 3, 5, 8, 12], labels=['1', '3', '5', '10', 'all'], fontsize=24) 
plt.yticks(np.arange(70, 90, 5), fontsize=24) 
plt.savefig('../figs/ds_6.7b_mbpp_test_cases.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#ds6.7b + humaneval


mean_base = [0.7252743902439024]
mean_plus = [0.6510670731707318]

ks = [5,10,20,25,50]
mbr_base_scores = [83.2774390244, 85.8231707317, 86.5243902439, 86.8902439024, 86.4329268293]
mbr_ape_base_scores = [84.2530487805, 86.4024390244, 86.8902439024, 87.2713414634, 87.0426829268]
ape_mbr_base_scores = [84.7103658537, 86.5243902439, 87.1951219512, 87.4237804878, 87.6524390244]
mbr_plus_scores = [79.4359756098,83.2926829268,85.0,85.5182926829,85.5182926829]
mbr_ape_plus_scores = [80.7774390244, 83.9634146341, 85.3658536585, 85.9756097561, 85.9756097561]
ape_mbr_plus_scores = [81.25, 84.3597560976, 85.7926829268, 86.3567073171, 87.0426829268]

filtering_mbr_base_scores = [87.6676829268,89.9695121951,91.5243902439,91.4634146341,91.6158536585]
filtering_mbr_ape_base_scores = [87.8506097561, 89.9695121951, 91.4634146341, 91.387195122, 91.4634146341]
filtering_ape_mbr_base_scores = [88.2317073171, 90.2743902439, 91.4024390244, 91.1585365854, 91.6158536585]
filtering_mbr_plus_scores = [83.506097561,87.1951219512,89.512195122,89.7865853659,90.7012195122]
filtering_mbr_ape_plus_scores = [84.0548780488, 87.3475609756, 89.4512195122, 89.7865853659, 90.3963414634]
filtering_ape_mbr_plus_scores = [84.5426829268, 87.8048780488, 89.512195122, 89.5579268293, 90.3963414634]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(6, 6))
base_oracle = [0.8925047289605567, 0.9160707633416659, 0.9332982999112066, 0.9381378091232159, 0.952097511234408]
plus_oracle = [0.8466633694345181, 0.8825810474346242, 0.908566600733767, 0.9152176753163815, 0.9323522266778692]
one_round_sd_ut_base = [0.8995697549885521, 0.9203007661693788, 0.937220635208886, 0.9422414196291166, 0.9565897085964037]
one_round_sd_ut_plus = [0.8582130664219024, 0.8912119686507713, 0.9148320565849617, 0.9207451700625989, 0.9352575197276148]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[2], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='MBR-Filter', linestyle='--', marker='o', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)

palette_dashed = sns.color_palette("dark:salmon_r", 6)  # Define a palette with 2 colors for dashed lines
sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='s', markersize=marker_size, color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='Filter+MBR', marker='s', markersize=marker_size, color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=base_oracle, label='Oracle', marker='s', markersize=marker_size, linestyle='--', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=16,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='upper left', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=1)
plt.xticks(np.arange(10, 60, 10), fontsize=24) 
plt.yticks(np.arange(85, 100, 5), fontsize=24)  # Adjust y-axis scale in steps of 5
plt.savefig('../figs/ds_6.7b_humaneval_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#ds6.7b + mbpp


mean_base = [0.6863291139240507]
mean_plus = [0.5859620253164557]



ks = [5,10,20,25,50]
mbr_base_scores = [80.2721518987, 82.4683544304, 83.5443037975, 83.6708860759, 83.9873417722]
mbr_ape_base_scores = [81.3291139241, 82.9367088608, 83.8481012658, 83.9240506329, 84.5569620253]
ape_mbr_base_scores = [82.0569620253, 83.417721519, 84.253164557, 84.4620253165, 84.8734177215]
mbr_plus_scores = [72.6582278481,75.746835443,77.5696202532,77.8797468354,78.6075949367]
mbr_ape_plus_scores = [73.3544303797, 75.835443038, 77.5189873418, 77.753164557, 78.7974683544]
ape_mbr_plus_scores = [74.4493670886, 76.7341772152, 78.2784810127, 78.6392405063, 79.3037974684]

filtering_mbr_base_scores = [82.8734177215,85.8607594937,87.5443037975,88.2594936709,89.1139240506]
filtering_mbr_ape_base_scores = [83.5316455696, 85.7974683544, 87.164556962, 87.9113924051, 88.9873417722]
filtering_ape_mbr_base_scores = [84.8227848101, 86.8860759494, 88.3544303797, 88.7974683544, 89.8734177215]
filtering_mbr_plus_scores = [74.5126582278,78.0759493671,80.3291139241,80.9810126582,82.0886075949]
filtering_mbr_ape_plus_scores = [75.0, 77.8227848101, 79.7974683544, 80.4113924051, 81.7088607595]
filtering_ape_mbr_plus_scores = [76.4493670886, 79.2278481013, 81.3670886076, 81.7405063291, 82.8481012658]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(6, 6))
base_oracle = [0.8499346886961866, 0.8874551277843814, 0.9129891336997442, 0.9188164631570279, 0.9318894361961269]
plus_oracle = [0.7596566378964325, 0.8029067501535389, 0.8339228587964082, 0.8411076767554778, 0.8564293970358527]
one_round_sd_ut_base = [0.8708834088620745, 0.9005950018442204, 0.9211778716442474, 0.9261359179377177, 0.9382134409196855]
one_round_sd_ut_plus = [0.7800107421264717, 0.8172536518860665, 0.8430379348929221, 0.8489190127486784, 0.8621558685060136]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[2], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='MBR-Filter', linestyle='--', marker='o', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)

palette_dashed = sns.color_palette("dark:salmon_r", 6)  # Define a palette with 2 colors for dashed lines
sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='s', markersize=marker_size, color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_base_scores, label='Filter+MBR', marker='s', markersize=marker_size, color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=base_oracle, label='Oracle', marker='s', markersize=marker_size, linestyle='--', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=16,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='upper left', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1, alpha=1)
plt.xticks(np.arange(10, 60, 10), fontsize=24) 
plt.yticks(np.arange(80, 95, 5), fontsize=24)  # Adjust y-axis scale in steps of 5
plt.savefig('../figs/ds_6.7b_mbpp_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#humaneval

ks = [5,10,20,25,50]
mbr_base_scores = [83.2774390244, 85.8231707317, 86.5243902439, 86.8902439024, 86.4329268293]
mbr_ape_base_scores = [84.2530487805, 86.4024390244, 86.8902439024, 87.2713414634, 87.0426829268]
ape_mbr_base_scores = [84.7103658537, 86.5243902439, 87.1951219512, 87.4237804878, 87.6524390244]
mbr_plus_scores = [79.4359756098,83.2926829268,85.0,85.5182926829,85.5182926829]
mbr_ape_plus_scores = [80.7774390244, 83.9634146341, 85.3658536585, 85.9756097561, 85.9756097561]
ape_mbr_plus_scores = [81.25, 84.3597560976, 85.7926829268, 86.3567073171, 87.0426829268]

filtering_mbr_base_scores = [87.6676829268,89.9695121951,91.5243902439,91.4634146341,91.6158536585]
filtering_mbr_ape_base_scores = [87.8506097561, 89.9695121951, 91.4634146341, 91.387195122, 91.4634146341]
filtering_ape_mbr_base_scores = [88.2317073171, 90.2743902439, 91.4024390244, 91.1585365854, 91.6158536585]
filtering_mbr_plus_scores = [83.506097561,87.1951219512,89.512195122,89.7865853659,90.7012195122]
filtering_mbr_ape_plus_scores = [84.0548780488, 87.3475609756, 89.4512195122, 89.7865853659, 90.3963414634]
filtering_ape_mbr_plus_scores = [84.5426829268, 87.8048780488, 89.512195122, 89.5579268293, 90.3963414634]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
base_oracle = [0.8925047289605567, 0.9160707633416659, 0.9332982999112066, 0.9381378091232159, 0.952097511234408]
plus_oracle = [0.8466633694345181, 0.8825810474346242, 0.908566600733767, 0.9152176753163815, 0.9323522266778692]
one_round_sd_ut_base = [0.8995697549885521, 0.9203007661693788, 0.937220635208886, 0.9422414196291166, 0.9565897085964037]
one_round_sd_ut_plus = [0.8582130664219024, 0.8912119686507713, 0.9148320565849617, 0.9207451700625989, 0.9352575197276148]

base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

plt.figure(figsize=(6, 6))
alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 10)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', marker='o', linestyle='--', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='SD-1-Filter', linestyle='--', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='SD-Multi-Filter', marker='o', color=palette[7], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Pass@k SD', marker='o', color=palette[9], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)


palette_blue = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors

palette_dashed = sns.color_palette("dark:salmon_r", 10)  # Define a palette with 2 colors for dashed lines
#sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR+', marker='o', linestyle='--', color=palette_dashed[0], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='MBR-Filter+', marker='o', linestyle='--', color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=mbr_ape_base_scores, 
             #label='SD-1', 
             marker='s', markersize=marker_size,
             color=palette_blue[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=ape_mbr_base_scores, 
             #label='SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_blue[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, 
             #label='Filter+SD-1', 
             marker='s', markersize=marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, 
             #label='Filter+SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_dashed[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=one_round_sd_ut_base, 
             #label='Oracle SD', 
             marker='s', markersize=marker_size,
             linestyle='--', color=palette_dashed[6], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=plus_oracle, label='Pass@k+', marker='o', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
plt.ylabel('Exec Acc', fontsize=24)
#plt.legend(
#    fontsize=14,
#    #title='methods', 
#    #title_fontsize='16',
#    shadow=False, 
#    fancybox=True, 
#    loc='right', 
#    framealpha=0.3,
#    #bbox_to_anchor=(1.05, 1) 
#)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(fontsize=24) 
plt.yticks(np.arange(85,100,5), fontsize=24) 
plt.savefig('../figs/ds_6.7b_humaneval_sd_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
#mbpp

# create lists for results above
ks = [5,10,20,25,50]
mbr_base_scores = [80.2721518987, 82.4683544304, 83.5443037975, 83.6708860759, 83.9873417722]
mbr_ape_base_scores = [81.3291139241, 82.9367088608, 83.8481012658, 83.9240506329, 84.5569620253]
ape_mbr_base_scores = [82.0569620253, 83.417721519, 84.253164557, 84.4620253165, 84.8734177215]
mbr_plus_scores = [72.6582278481,75.746835443,77.5696202532,77.8797468354,78.6075949367]
mbr_ape_plus_scores = [73.3544303797, 75.835443038, 77.5189873418, 77.753164557, 78.7974683544]
ape_mbr_plus_scores = [74.4493670886, 76.7341772152, 78.2784810127, 78.6392405063, 79.3037974684]

filtering_mbr_base_scores = [82.8734177215,85.8607594937,87.5443037975,88.2594936709,89.1139240506]
filtering_mbr_ape_base_scores = [83.5316455696, 85.7974683544, 87.164556962, 87.9113924051, 88.9873417722]
filtering_ape_mbr_base_scores = [84.8227848101, 86.8860759494, 88.3544303797, 88.7974683544, 89.8734177215]
filtering_mbr_plus_scores = [74.5126582278,78.0759493671,80.3291139241,80.9810126582,82.0886075949]
filtering_mbr_ape_plus_scores = [75.0, 77.8227848101, 79.7974683544, 80.4113924051, 81.7088607595]
filtering_ape_mbr_plus_scores = [76.4493670886, 79.2278481013, 81.3670886076, 81.7405063291, 82.8481012658]

# draw line plot for MBR base, MBR->APE base, APE->MBR base, MBR plus, MBR->APE plus, APE->MBR plus, both in filtering and without filtering
# use seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
base_oracle = [0.8499346886961866, 0.8874551277843814, 0.9129891336997442, 0.9188164631570279, 0.9318894361961269]
plus_oracle = [0.7596566378964325, 0.8029067501535389, 0.8339228587964082, 0.8411076767554778, 0.8564293970358527]
one_round_sd_ut_base = [0.8708834088620745, 0.9005950018442204, 0.9211778716442474, 0.9261359179377177, 0.9382134409196855]
one_round_sd_ut_plus = [0.7800107421264717, 0.8172536518860665, 0.8430379348929221, 0.8489190127486784, 0.8621558685060136]
# for each number in the lists above, times 100
base_oracle = [x * 100 for x in base_oracle]
plus_oracle = [x * 100 for x in plus_oracle]
one_round_sd_ut_base = [x * 100 for x in one_round_sd_ut_base]
one_round_sd_ut_plus = [x * 100 for x in one_round_sd_ut_plus]

plt.figure(figsize=(6, 6))
alpha = 0.9
line_width = 3
marker_size = 8
palette = sns.color_palette("ch:start=.2,rot=-.3", 10)  # Define a palette with 3 colors
#sns.lineplot(x=ks, y=mbr_base_scores, label='MBR', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', marker='o', linestyle='--', color=palette[1], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', marker='o', linestyle='--', color=palette[3], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='SD-1-Filter', linestyle='--', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='SD-Multi-Filter', marker='o', color=palette[7], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[5], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Pass@k SD', marker='o', color=palette[9], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=base_oracle, label='Pass@k', marker='o', color=palette[4], alpha=alpha, linewidth=line_width)


palette_blue = sns.color_palette("ch:start=.2,rot=-.3", 7)  # Define a palette with 3 colors

palette_dashed = sns.color_palette("dark:salmon_r", 10)  # Define a palette with 2 colors for dashed lines
#sns.lineplot(x=ks, y=mbr_plus_scores, label='MBR+', marker='o', linestyle='--', color=palette_dashed[0], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=filtering_mbr_plus_scores, label='MBR-Filter+', marker='o', linestyle='--', color=palette_dashed[2], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=mbr_ape_base_scores, label='SD-1', 
             marker='s', markersize=marker_size,
             color=palette_blue[1], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=ape_mbr_base_scores, label='SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_blue[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_mbr_ape_base_scores, label='Filter+SD-1', 
             marker='s', markersize=marker_size,
             color=palette_dashed[0], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=filtering_ape_mbr_base_scores, label='Filter+SD-Multi', 
             marker='s', markersize=marker_size,
             color=palette_dashed[3], alpha=alpha, linewidth=line_width)
sns.lineplot(x=ks, y=one_round_sd_ut_base, label='Oracle SD', 
             marker='s', markersize=marker_size,
             linestyle='--', color=palette_dashed[6], alpha=alpha, linewidth=line_width)
#sns.lineplot(x=ks, y=plus_oracle, label='Pass@k+', marker='o', color=palette_dashed[4], alpha=alpha, linewidth=line_width)

#plt.title('HumanEval', fontsize=30, alpha=alpha)
plt.xlabel('# Candidates', fontsize=24)
#plt.ylabel('Exec Acc', fontsize=24)
plt.legend(
    fontsize=14,
    #title='methods', 
    #title_fontsize='16',
    shadow=False, 
    fancybox=True, 
    loc='lower right', 
    framealpha=0.3,
    #bbox_to_anchor=(1.05, 1) 
)
plt.grid(True, linestyle='-', linewidth=1)
plt.xticks(fontsize=24) 
plt.yticks(np.arange(80,100,5), fontsize=24) 
plt.savefig('../figs/ds_6.7b_mbpp_sd_candidates_base.jpg', dpi=300, bbox_inches='tight', pad_inches = 0.01)
plt.show()
